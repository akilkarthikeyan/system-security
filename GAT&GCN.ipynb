# In-degree for all nodes:  {1: 26, 2: 20, 3: 22, 4: 23, 5: 32, 6: 25, 7: 22, 8: 24, 9: 29, 10: 29, 11: 22, 12: 26, 13: 20, 14: 26, 15: 26, 16: 13, 17: 29, 18: 29, 19: 27, 20: 25, 21: 23, 22: 24, 23: 26, 24: 24, 25: 22, 26: 20, 27: 26, 28: 23, 29: 24, 30: 24, 31: 21, 32: 19, 33: 22, 34: 25, 35: 32, 36: 25, 37: 23, 38: 31, 39: 25, 40: 21, 41: 31, 42: 26, 43: 25, 44: 24, 45: 30, 46: 25, 47: 18, 48: 20, 49: 22, 50: 22}
# Out degree for all nodes:  {1: 23, 2: 19, 3: 23, 4: 27, 5: 24, 6: 25, 7: 23, 8: 24, 9: 29, 10: 21, 11: 19, 12: 23, 13: 26, 14: 19, 15: 24, 16: 30, 17: 23, 18: 26, 19: 22, 20: 27, 21: 28, 22: 22, 23: 23, 24: 24, 25: 28, 26: 25, 27: 23, 28: 23, 29: 15, 30: 24, 31: 27, 32: 24, 33: 32, 34: 27, 35: 26, 36: 27, 37: 23, 38: 23, 39: 25, 40: 26, 41: 27, 42: 30, 43: 24, 44: 20, 45: 22, 46: 23, 47: 26, 48: 26, 49: 24, 50: 24}

# %%
edge=list(G.edges)
print("List of all edges: ", edge)
# Out:
# List of all edges:  [(1, 2), (1, 5), (1, 6), (1, 7), (1, 9), (1, 12), (1, 19), (1, 20), (1, 22), (1, 25), (1, 26), (1, 28), (1, 29), (1, 32), (1, 34), (1, 35), (1, 36), (1, 38), (1, 41), (1, 42), (1, 43), (1, 45), (1, 46), (2, 1), (2, 3), (2, 6), (2, 9), (2, 10), (2, 12), (2, 14), (2, 15), (2, 17), (2, 21), (2, 30), (2, 31), (2, 33), (2, 34), (2, 36), (2, 37), (2, 39), (2, 41), (2, 44), (3, 1), (3, 4), (3, 9), (3, 10), (3, 11), (3, 12), (3, 16), (3, 17), (3, 19), (3, 20), (3, 24), (3, 27), (3, 29), (3, 32), (3, 33), (3, 34), (3, 35), (3, 41), (3, 44), (3, 45), (3, 46), (3, 48), (3, 50), (4, 1), (4, 3), (4, 5), (4, 9), (4, 10), (4, 12), (4, 14), (4, 15), (4, 17), (4, 18), (4, 19), (4, 22), (4, 25), (4, 26), (4, 27), (4, 28), (4, 29), (4, 31), (4, 33), (4, 36), (4, 39), (4, 40), (4, 41), (4, 43), (4, 44), (4, 48), (4, 49), (5, 1), (5, 3), (5, 7), (5, 13), (5, 14), (5, 15), (5, 16), (5, 17), (5, 19), (5, 20), (5, 22), (5, 24), (5, 27), (5, 28), (5, 29), (5, 30), (5, 31), (5, 32), (5, 34
# ...

# %%
for i in list(G.nodes()):
    G.nodes[i]['call_count'] = indegree[i]

# %% [markdown]
# **Creating csv file**

# %%
import csv

# %% [markdown]
# *writing the call counts in an excel sheet*

# %%
with open('calls.csv', 'w') as f:
    for key in indegree.keys():
        f.write("%s,%s\n"%(key,indegree[key]))

# %% [markdown]
# ### Creating DataFrames and Series for GAT input

# %%
import pandas as pd

# %% [markdown]
# *Loading the dataset from excel and converting it into dataframe*

# %%
df = pd.read_excel("GAT(1).xlsx")

# %% [markdown]
# *Mentioning source and destination of each edge for creating input, which has to be given to GAT*

# %%
s=[]
d=[]
for i in range(len(edges)):
  s.append(edges[i][0]-1)
  d.append(edges[i][1]-1)

# %%
#!pip install StellarGraph
from stellargraph import StellarGraph
from stellargraph import StellarDiGraph

# %% [markdown]
# *The source and destination is converted into a dataframe and given as input*

# %%
square_edges = pd.DataFrame(
    {"source": s, "target": d}
)
square_edges
# Out:
#       source  target
# 0          0       1
# 1          0       4
# 2          0       5
# 3          0       6
# 4          0       8
# ...      ...     ...
# 1213      49      40
# 1214      49      42
# 1215      49      44
# 1216      49      45
# 1217      49      46
#
# [1218 rows x 2 columns]

# %% [markdown]
# *The data retrieved from the GAT.xlsx is converted into a dataframe which consists only of node features(dependency,codeql,call_count)*

# %%
dependency=df.dependency
codeql=df.codeql 
call_count=df.call_count

# %%
square_node_data = pd.DataFrame(
    {"dependency": dependency, "codeql": codeql, "call_count":call_count}, index=list(range(0,50))
)
square_node_data
# Out:
#     dependency  codeql  call_count
# 0           67      68          26
# 1           86      82          20
# 2           97      98          22
# 3           34      55          23
# 4           68      85          32
# 5           46      66          25
# 6           79      74          22
# 7           62      73          24
# 8           83      90          29
# 9           91      69          29
# 10          69      85          22
# 11          85      85          26
# 12          60      72          20
# 13          68      72          26
# 14          64      56          26
# 15          42      58          13
# 16          75      51          29
# 17          32      61          29
# 18          42      83          27
# 19          80      57          25
# 20          84      91          23
# 21          66      94          24
# 22          79      74          26
# 23          29      50          24
# 24          53      60          22
# 25          53      98          20
# ...

# %% [markdown]
# *Both the edges(square_edges) and node features(square_node_data) are given as input to create a directed graph which is used for training*
#
# - Note: We did not use any edge features as of now, but we can include edge features and edge weight also in the future.

# %%
G = StellarDiGraph(square_node_data,square_edges)
print(G.info())
# Out:
# StellarDiGraph: Directed multigraph
#  Nodes: 50, Edges: 1218
#
#  Node types:
#   default: [50]
#     Features: float32 vector, length 3
#     Edge types: default-default->default
#
#  Edge types:
#     default-default->default: [1218]
#         Weights: all 1 (default)
#         Features: none

# %% [markdown]
# *Categorizing the score(label) into 'low', 'Moderate', 'High' and 'Critical'*
#
# - The score is also in GAT.xlsx.
#
# - The score was calculated using the formula:-
#
#       score= (dependency + codeql)/2 *(call_count/avg(call_counts))

# %%
import numpy as np

# %%
node_subjects=["Low","Critical","Moderate","High"]
score=[]
for i in range(len(df.score)):
  if(df.score[i]<60):
    score.append("Low")
  elif(df.score[i]<75):
    score.append("Moderate")
  elif(df.score[i]<90):
    score.append("High")
  else:
    score.append("Critical")
data = np.array(score)
labels = pd.Series(data)
print(labels)
# Out:
# 0     Moderate
# 1     Moderate
# 2         High
# 3          Low
# 4     Critical
# 5          Low
# 6     Moderate
# 7     Moderate
# 8     Critical
# 9     Critical
# 10    Moderate
# 11    Critical
# 12         Low
# 13        High
# 14    Moderate
# 15         Low
# 16        High
# 17         Low
# 18    Moderate
# 19    Moderate
# 20        High
# 21        High
# 22        High
# 23         Low
# 24         Low
# 25    Moderate
# 26        High
# 27        High
# 28         Low
# 29    Moderate
# 30    Moderate
# 31         Low
# 32        High
# 33         Low
# 34        High
# 35    Moderate
# 36         Low
# 37    Moderate
# 38    Moderate
# 39         Low
# 40        High
# 41        High
# 42    Moderate
# 43    Moderate
# 44        High
# 45    Moderate
# 46         Low
# 47        High
# 48    Moderate
# 49         Low
# dtype: object

# %%
node_subjects
# Out:
# ['Low', 'Critical', 'Moderate', 'High']

# %% [markdown]
# ### Creating model

# %%
pip install stellargraph

# %%
import networkx as nx
import pandas as pd
import os

import stellargraph as sg
from stellargraph.mapper import FullBatchNodeGenerator
from stellargraph.layer import GAT

from tensorflow.keras import layers, optimizers, losses, metrics, Model
from sklearn import preprocessing, feature_extraction, model_selection
from stellargraph import datasets
from IPython.display import display, HTML
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ***Use this for training a GCN model***

# %%
from stellargraph.layer import GCN

# %% [markdown]
# *Splitting dataset into train, validation, test*

# %%
train_subjects, test_subjects = model_selection.train_test_split(
    labels, train_size=30, test_size=None, stratify=labels
)
val_subjects, test_subjects = model_selection.train_test_split(
    test_subjects, train_size=10, test_size=None, stratify=test_subjects
)

# %% [markdown]
# *Distribution of training data*

# %%
from collections import Counter

Counter(train_subjects)
# Out:
# Counter({'High': 8, 'Moderate': 11, 'Low': 9, 'Critical': 2})

# %% [markdown]
# *Encoding dataset for generalization*

# %%
target_encoding = preprocessing.LabelBinarizer()

train_targets = target_encoding.fit_transform(train_subjects)
val_targets = target_encoding.transform(val_subjects)
test_targets = target_encoding.transform(test_subjects)

# %%
train_targets

# %%
train_subjects

# %%
generator = FullBatchNodeGenerator(G, method="gat")

# %%
train_gen = generator.flow(train_subjects.index, train_targets)

# %% [markdown]
# *Hyperparameters*
#
# - the layer_sizes is a list of hidden feature sizes of each layer in the model. In this example we use two GAT layers with 8-dimensional hidden node features for the first layer and the 4 class classification output for the second layer.
#
# - attn_heads is the number of attention heads in all but the last GAT layer in the model
#
# - activations is a list of activations applied to each layer’s output
#
# - Arguments such as bias, in_dropout, attn_dropout are internal parameters of the model.

# %%
gat = GAT(
    layer_sizes=[8, train_targets.shape[1]],
    activations=["elu","softmax"],
    attn_heads=8,
    generator=generator,
    in_dropout=0.5,
    attn_dropout=0.5,
    normalize=None,
)

# %% [markdown]
# ***Use the following code block instead of the previous one if you want to train a GCD model***

# %%
gat = GCN(
    layer_sizes=[8, train_targets.shape[1]],
    activations=["elu","softmax"],
    generator=generator,
    dropout=0.5,
)

# %%
x_inp, predictions = gat.in_out_tensors()

# %% [markdown]
# ### Training model

# %%
model = Model(inputs=x_inp, outputs=predictions)
model.compile(
    optimizer=optimizers.Adam(lr=0.005),
    loss=losses.categorical_crossentropy,
    metrics=["acc"],
)

# %%
val_gen = generator.flow(val_subjects.index, val_targets)

# %% [markdown]
# *For early stopping if validation accuracy stops improving*

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

if not os.path.isdir("logs"):
    os.makedirs("logs")
es_callback = EarlyStopping(
    monitor="val_acc", patience=20
)  # patience is the number of epochs to wait before early stopping in case of no further improvement
mc_callback = ModelCheckpoint(
    "logs/best_model.h5", monitor="val_acc", save_best_only=True, save_weights_only=True
)

# %%
history = model.fit(
    train_gen,
    epochs=50,
    validation_data=val_gen,
    verbose=2,
    shuffle=False,  # this should be False, since shuffling data means shuffling the whole graph
    callbacks=[es_callback, mc_callback],
)
# Out:
# Epoch 1/50
# 1/1 - 1s - loss: 11.8199 - acc: 0.2667 - val_loss: 11.2827 - val_acc: 0.3000 - 1s/epoch - 1s/step
# Epoch 2/50
# 1/1 - 0s - loss: 11.8199 - acc: 0.2667 - val_loss: 11.2827 - val_acc: 0.3000 - 49ms/epoch - 49ms/step
# Epoch 3/50
# 1/1 - 0s - loss: 10.9754 - acc: 0.2667 - val_loss: 11.2827 - val_acc: 0.3000 - 49ms/epoch - 49ms/step
# Epoch 4/50
# 1/1 - 0s - loss: 10.9571 - acc: 0.2667 - val_loss: 11.2827 - val_acc: 0.3000 - 52ms/epoch - 52ms/step
# Epoch 5/50
# 1/1 - 0s - loss: 11.8199 - acc: 0.2667 - val_loss: 10.0302 - val_acc: 0.3000 - 45ms/epoch - 45ms/step
# Epoch 6/50
# 1/1 - 0s - loss: 11.4146 - acc: 0.2667 - val_loss: 9.9476 - val_acc: 0.3000 - 56ms/epoch - 56ms/step
# Epoch 7/50
# 1/1 - 0s - loss: 10.9300 - acc: 0.2667 - val_loss: 9.9188 - val_acc: 0.3000 - 47ms/epoch - 47ms/step
# Epoch 8/50
# 1/1 - 0s - loss: 10.8915 - acc: 0.2667 - val_loss: 9.9063 - val_acc: 0.3000 - 47ms/epoch - 47ms/step
# Epoch 9/50
# ...

# %%
sg.utils.plot_history(history)

# %% [markdown]
# *Saving model*

# %%
model.load_weights("logs/best_model.h5")

# %% [markdown]
# ### Evaluating test data

# %%
test_gen = generator.flow(test_subjects.index, test_targets)

# %%
test_metrics = model.evaluate(test_gen)
print("\nTest Set Metrics:")
for name, val in zip(model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
# 1/1 [==============================] - 0s 37ms/step - loss: 11.2827 - acc: 0.3000
#
# Test Set Metrics:
# 	loss: 11.2827
# 	acc: 0.3000

# %%
all_nodes = labels.index
all_gen = generator.flow(all_nodes)
all_predictions = model.predict(all_gen)
# Out:
# 1/1 [==============================] - 0s 109ms/step

# %%
node_predictions = target_encoding.inverse_transform(all_predictions.squeeze())

# %%
df = pd.DataFrame({"Predicted": node_predictions, "True": labels})
df.head(20)
# Out:
#    Predicted      True
# 0       High  Moderate
# 1       High  Moderate
# 2       High      High
# 3       High       Low
# 4       High  Critical
# 5       High       Low
# 6       High  Moderate
# 7       High  Moderate
# 8       High  Critical
# 9       High  Critical
# 10      High  Moderate
# 11      High  Critical
# 12      High       Low
# 13      High      High
# 14      High  Moderate
# 15      High       Low
# 16      High      High
# 17      High       Low
# 18      High  Moderate
# 19      High  Moderate

# %% [markdown]
# ### Inference

# %% [markdown]
# *Conclusion*
#
# - The graph we used was generated randomly.
# - The node features**(dependency and codeql)** was generated randomly.
# - the **call_count** was derived using the in-degree of each node.
# - The ratio of edges and nodes in our graph is too high, hence there is a possibility of over-smoothing.
# - The score(label) was calculated using the formula:-
#
#       score= (dependency + codeql)/2 *(call_count/avg(call_counts))
# - The model is not fine-tuned
#
# Thus the results are poor. We have also tried using GCN, but there was no significant improvement. The hyperparameters were also changed several times with no avail.

# %% [markdown]
# *Doubts*
#
# - What should be our label?
# - Are the given node features relevant?
# - Is it better to use supervised or unsupervised learning?
